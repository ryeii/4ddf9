# %%
import functools
import logging
import time

import numpy as np
import torch
from torch.distributions.multivariate_normal import MultivariateNormal

logger = logging.getLogger(__name__)


def _ensure_non_zero(cost, beta, factor):
    return torch.exp(-factor * (cost - beta))


def is_tensor_like(x):
    return torch.is_tensor(x) or type(x) is np.ndarray


def squeeze_n(v, n_squeeze):
    for _ in range(n_squeeze):
        v = v.squeeze(0)
    return v


# from arm_pytorch_utilities, standalone since that package is not on pypi yet
def handle_batch_input(n):
    def _handle_batch_input(func):
        """For func that expect 2D input, handle input that have more than 2 dimensions by flattening them temporarily"""

        @functools.wraps(func)
        def wrapper(*args, **kwargs):
            # assume inputs that are tensor-like have compatible shapes and is represented by the first argument
            batch_dims = []
            for arg in args:
                if is_tensor_like(arg):
                    if len(arg.shape) > n:
                        # last dimension is type dependent; all previous ones are batches
                        batch_dims = arg.shape[:-(n - 1)]
                        break
                    elif len(arg.shape) < n:
                        n_batch_dims_to_add = n - len(arg.shape)
                        batch_ones_to_add = [1] * n_batch_dims_to_add
                        args = [v.view(*batch_ones_to_add, *v.shape) if is_tensor_like(v) else v for v in args]
                        ret = func(*args, **kwargs)
                        if isinstance(ret, tuple):
                            ret = [squeeze_n(v, n_batch_dims_to_add) if is_tensor_like(v) else v for v in ret]
                            return ret
                        else:
                            if is_tensor_like(ret):
                                return squeeze_n(ret, n_batch_dims_to_add)
                            else:
                                return ret
            # no batches; just return normally
            if not batch_dims:
                return func(*args, **kwargs)

            # reduce all batch dimensions down to the first one
            args = [v.view(-1, *v.shape[-(n - 1):]) if (is_tensor_like(v) and len(v.shape) > 2) else v for v in args]
            ret = func(*args, **kwargs)
            # restore original batch dimensions; keep variable dimension (nx)
            if type(ret) is tuple:
                ret = [v if (not is_tensor_like(v) or len(v.shape) == 0) else (
                    v.view(*batch_dims, *v.shape[-(n - 1):]) if len(v.shape) == n else v.view(*batch_dims)) for v in
                       ret]
            else:
                if is_tensor_like(ret):
                    if len(ret.shape) == n:
                        ret = ret.view(*batch_dims, *ret.shape[-(n - 1):])
                    else:
                        ret = ret.view(*batch_dims)
            return ret

        return wrapper

    return _handle_batch_input


class MPPI():
    """
    Model Predictive Path Integral control
    This implementation batch samples the trajectories and so scales well with the number of samples K.

    Implemented according to algorithm 2 in Williams et al., 2017
    'Information Theoretic MPC for Model-Based Reinforcement Learning',
    based off of https://github.com/ferreirafabio/mppi_pendulum
    """

    def __init__(self, dynamics, running_cost, nx, noise_sigma, num_samples=100, horizon=15, device="cpu",
                 terminal_state_cost=None,
                 lambda_=1.,
                 noise_mu=None,
                 u_min=None,
                 u_max=None,
                 u_init=None,
                 U_init=None,
                 u_scale=1,
                 u_per_command=1,
                 step_dependent_dynamics=False,
                 rollout_samples=1,
                 rollout_var_cost=0,
                 rollout_var_discount=0.95,
                 sample_null_action=False,
                 noise_abs_cost=False):
        """
        :param dynamics: function(state, action) -> next_state (K x nx) taking in batch state (K x nx) and action (K x nu)
        :param running_cost: function(state, action) -> cost (K) taking in batch state and action (same as dynamics)
        :param nx: state dimension
        :param noise_sigma: (nu x nu) control noise covariance (assume v_t ~ N(u_t, noise_sigma))
        :param num_samples: K, number of trajectories to sample
        :param horizon: T, length of each trajectory
        :param device: pytorch device
        :param terminal_state_cost: function(state) -> cost (K x 1) taking in batch state
        :param lambda_: temperature, positive scalar where larger values will allow more exploration
        :param noise_mu: (nu) control noise mean (used to bias control samples); defaults to zero mean
        :param u_min: (nu) minimum values for each dimension of control to pass into dynamics
        :param u_max: (nu) maximum values for each dimension of control to pass into dynamics
        :param u_init: (nu) what to initialize new end of trajectory control to be; defeaults to zero
        :param U_init: (T x nu) initial control sequence; defaults to noise
        :param step_dependent_dynamics: whether the passed in dynamics needs horizon step passed in (as 3rd arg)
        :param rollout_samples: M, number of state trajectories to rollout for each control trajectory
            (should be 1 for deterministic dynamics and more for models that output a distribution)
        :param rollout_var_cost: Cost attached to the variance of costs across trajectory rollouts
        :param rollout_var_discount: Discount of variance cost over control horizon
        :param sample_null_action: Whether to explicitly sample a null action (bad for starting in a local minima)
        :param noise_abs_cost: Whether to use the absolute value of the action noise to avoid bias when all states have the same cost
        """
        self.d = device
        self.dtype = noise_sigma.dtype
        self.K = num_samples  # N_SAMPLES
        self.T = horizon  # TIMESTEPS

        # dimensions of state and control
        self.nx = nx
        self.nu = 1 if len(noise_sigma.shape) == 0 else noise_sigma.shape[0]
        self.lambda_ = lambda_

        if noise_mu is None:
            noise_mu = torch.zeros(self.nu, dtype=self.dtype)

        if u_init is None:
            u_init = torch.zeros_like(noise_mu)

        # handle 1D edge case
        if self.nu == 1:
            noise_mu = noise_mu.view(-1)
            noise_sigma = noise_sigma.view(-1, 1)

        # bounds
        self.u_min = u_min
        self.u_max = u_max
        self.u_scale = u_scale
        self.u_per_command = u_per_command
        # make sure if any of them is specified, both are specified
        if self.u_max is not None and self.u_min is None:
            if not torch.is_tensor(self.u_max):
                self.u_max = torch.tensor(self.u_max)
            self.u_min = -self.u_max
        if self.u_min is not None and self.u_max is None:
            if not torch.is_tensor(self.u_min):
                self.u_min = torch.tensor(self.u_min)
            self.u_max = -self.u_min
        if self.u_min is not None:
            self.u_min = self.u_min.to(device=self.d)
            self.u_max = self.u_max.to(device=self.d)

        self.noise_mu = noise_mu.to(self.d)
        self.noise_sigma = noise_sigma.to(self.d)
        self.noise_sigma_inv = torch.inverse(self.noise_sigma)
        self.noise_dist = MultivariateNormal(self.noise_mu, covariance_matrix=self.noise_sigma)
        # T x nu control sequence
        self.U = U_init
        self.u_init = u_init.to(self.d)

        if self.U is None:
            self.U = self.noise_dist.sample((self.T,))

        self.step_dependency = step_dependent_dynamics
        self.F = dynamics
        self.running_cost = running_cost
        self.terminal_state_cost = terminal_state_cost
        self.sample_null_action = sample_null_action
        self.noise_abs_cost = noise_abs_cost
        self.state = None

        # handling dynamics models that output a distribution (take multiple trajectory samples)
        self.M = rollout_samples
        self.rollout_var_cost = rollout_var_cost
        self.rollout_var_discount = rollout_var_discount

        # sampled results from last command
        self.cost_total = None
        self.cost_total_non_zero = None
        self.omega = None
        self.states = None
        self.actions = None

    @handle_batch_input(n=2)
    def _dynamics(self, state, u, t):
        return self.F(state, u, t) if self.step_dependency else self.F(state, u)

    @handle_batch_input(n=2)
    def _running_cost(self, state, u):
        return self.running_cost(state, u)

    def command(self, state, shift_nominal_trajectory=True):
        """
        :param state: (nx) or (K x nx) current state, or samples of states (for propagating a distribution of states)
        :param shift_nominal_trajectory: Whether to roll the nominal trajectory forward one step. This should be True
        if the command is to be executed. If the nominal trajectory is to be refined then it should be False.
        :returns action: (nu) best action
        """
        if shift_nominal_trajectory:
            # shift command 1 time step
            self.U = torch.roll(self.U, -1, dims=0)
            self.U[-1] = self.u_init

        return self._command(state)

    def _command(self, state):
        if not torch.is_tensor(state):
            state = torch.tensor(state)
        self.state = state.to(dtype=self.dtype, device=self.d)
        cost_total = self._compute_total_cost_batch()
        beta = torch.min(cost_total)
        self.cost_total_non_zero = _ensure_non_zero(cost_total, beta, 1 / self.lambda_)
        eta = torch.sum(self.cost_total_non_zero)
        self.omega = (1. / eta) * self.cost_total_non_zero
        perturbations = []
        for t in range(self.T):
            perturbations.append(torch.sum(self.omega.view(-1, 1) * self.noise[:, t], dim=0))
        perturbations = torch.stack(perturbations)
        self.U = self.U + perturbations
        action = self.U[:self.u_per_command]
        # reduce dimensionality if we only need the first command
        if self.u_per_command == 1:
            action = action[0]
        return action

    def change_horizon(self, horizon):
        if horizon < self.U.shape[0]:
            # truncate trajectory
            self.U = self.U[:horizon]
        elif horizon > self.U.shape[0]:
            # extend with u_init
            self.U = torch.cat((self.U, self.u_init.repeat(horizon - self.U.shape[0], 1)))
        self.T = horizon

    def reset(self):
        """
        Clear controller state after finishing a trial
        """
        self.U = self.noise_dist.sample((self.T,))

    def _compute_rollout_costs(self, perturbed_actions):
        K, T, nu = perturbed_actions.shape
        assert nu == self.nu

        cost_total = torch.zeros(K, device=self.d, dtype=self.dtype)
        cost_samples = cost_total.repeat(self.M, 1)
        cost_var = torch.zeros_like(cost_total)

        # allow propagation of a sample of states (ex. to carry a distribution), or to start with a single state
        if self.state.shape == (K, self.nx):
            state = self.state
        else:
            state = self.state.view(1, -1).repeat(K, 1)

        # rollout action trajectory M times to estimate expected cost
        state = state.repeat(self.M, 1, 1)

        states = []
        actions = []
        for t in range(T):
            u = self.u_scale * perturbed_actions[:, t].repeat(self.M, 1, 1)
            state = self._dynamics(state, u, t)
            c = self._running_cost(state, u)
            cost_samples = cost_samples + c
            if self.M > 1:
                cost_var += c.var(dim=0) * (self.rollout_var_discount ** t)

            # Save total states/actions
            states.append(state)
            actions.append(u)

        # Actions is K x T x nu
        # States is K x T x nx
        actions = torch.stack(actions, dim=-2)
        states = torch.stack(states, dim=-2)

        # action perturbation cost
        if self.terminal_state_cost:
            c = self.terminal_state_cost(states, actions)
            cost_samples = cost_samples + c
        cost_total = cost_total + cost_samples.mean(dim=0)
        cost_total = cost_total + cost_var * self.rollout_var_cost
        return cost_total, states, actions

    def _compute_total_cost_batch(self):
        # parallelize sampling across trajectories
        # resample noise each time we take an action
        noise = self.noise_dist.rsample((self.K, self.T))
        # broadcast own control to noise over samples; now it's K x T x nu
        perturbed_action = self.U + noise
        if self.sample_null_action:
            perturbed_action[self.K - 1] = 0
        # naively bound control
        self.perturbed_action = self._bound_action(perturbed_action)
        # bounded noise after bounding (some got cut off, so we don't penalize that in action cost)
        self.noise = self.perturbed_action - self.U
        if self.noise_abs_cost:
            action_cost = self.lambda_ * torch.abs(self.noise) @ self.noise_sigma_inv
            # NOTE: The original paper does self.lambda_ * torch.abs(self.noise) @ self.noise_sigma_inv, but this biases
            # the actions with low noise if all states have the same cost. With abs(noise) we prefer actions close to the
            # nomial trajectory.
        else:
            action_cost = self.lambda_ * self.noise @ self.noise_sigma_inv  # Like original paper

        rollout_cost, self.states, actions = self._compute_rollout_costs(self.perturbed_action)
        self.actions = actions / self.u_scale

        # action perturbation cost
        perturbation_cost = torch.sum(self.U * action_cost, dim=(1, 2))
        self.cost_total = rollout_cost + perturbation_cost
        return self.cost_total

    def _bound_action(self, action):
        if self.u_max is not None:
            for t in range(self.T):
                u = action[:, self._slice_control(t)]
                cu = torch.max(torch.min(u, self.u_max), self.u_min)
                action[:, self._slice_control(t)] = cu
        return action

    def _slice_control(self, t):
        return slice(t * self.nu, (t + 1) * self.nu)

    def get_rollouts(self, state, num_rollouts=1):
        """
            :param state: either (nx) vector or (num_rollouts x nx) for sampled initial states
            :param num_rollouts: Number of rollouts with same action sequence - for generating samples with stochastic
                                 dynamics
            :returns states: num_rollouts x T x nx vector of trajectories

        """
        state = state.view(-1, self.nx)
        if state.size(0) == 1:
            state = state.repeat(num_rollouts, 1)

        T = self.U.shape[0]
        states = torch.zeros((num_rollouts, T + 1, self.nx), dtype=self.U.dtype, device=self.U.device)
        states[:, 0] = state
        for t in range(T):
            states[:, t + 1] = self._dynamics(states[:, t].view(num_rollouts, -1),
                                              self.u_scale * self.U[t].view(num_rollouts, -1), t)
        return states[:, 1:]


def run_mppi(mppi, env, retrain_dynamics, retrain_after_iter=50, iter=1000, render=True):
    dataset = torch.zeros((retrain_after_iter, mppi.nx + mppi.nu), dtype=mppi.U.dtype, device=mppi.d)
    total_reward = 0
    for i in range(iter):
        state = env.state.copy()
        command_start = time.perf_counter()
        action = mppi.command(state)
        elapsed = time.perf_counter() - command_start
        s, r, _, _ = env.step(action.cpu().numpy())
        total_reward += r
        logger.debug("action taken: %.4f reward received: %.4f time taken: %.5fs", action, r, elapsed)
        if render:
            env.render()

        di = i % retrain_after_iter
        if di == 0 and i > 0:
            retrain_dynamics(dataset)
            # don't have to clear dataset since it'll be overridden, but useful for debugging
            dataset.zero_()
        dataset[di, :mppi.nx] = torch.tensor(state, dtype=mppi.U.dtype)
        dataset[di, mppi.nx:] = action
    return total_reward, dataset

# %%
import gym
import numpy as np
import torch
import logging
import math
from gym import wrappers, logger as gym_log

gym_log.set_level(gym_log.INFO)
logger = logging.getLogger(__name__)
logging.basicConfig(level=logging.DEBUG,
                    format='[%(levelname)s %(asctime)s %(pathname)s:%(lineno)d] %(message)s',
                    datefmt='%m-%d %H:%M:%S')

ENV_NAME = "Pendulum-v1"
TIMESTEPS = 15  # T
N_SAMPLES = 100  # K
ACTION_LOW = -2.0
ACTION_HIGH = 2.0

d = "cuda"
dtype = torch.double

noise_sigma = torch.tensor(10, device=d, dtype=dtype)
# noise_sigma = torch.tensor([[10, 0], [0, 10]], device=d, dtype=dtype)
lambda_ = 1.


def dynamics(state, perturbed_action):
    # true dynamics from gym
    th = state[:, 0].view(-1, 1)
    thdot = state[:, 1].view(-1, 1)

    g = 10
    m = 1
    l = 1
    dt = 0.05

    u = perturbed_action
    u = torch.clamp(u, -2, 2)

    newthdot = thdot + (-3 * g / (2 * l) * np.sin(th + np.pi) + 3. / (m * l ** 2) * u) * dt
    newth = th + newthdot * dt
    newthdot = torch.clamp(newthdot, -8, 8)

    state = torch.cat((newth, newthdot), dim=1)
    return state


def angle_normalize(x):
    return (((x + math.pi) % (2 * math.pi)) - math.pi)


def running_cost(state, action):
    theta = state[:, 0]
    theta_dt = state[:, 1]
    action = action[:, 0]
    cost = angle_normalize(theta) ** 2 + 0.1 * theta_dt ** 2
    return cost


def train(new_data):
    pass


downward_start = False
env = gym.make(ENV_NAME).env  # bypass the default TimeLimit wrapper
env.reset()
if downward_start:
    env.state = [np.pi, 1]
nx = 2
mppi_gym = MPPI(dynamics, running_cost, nx, noise_sigma, num_samples=N_SAMPLES, horizon=TIMESTEPS,
                        lambda_=lambda_)

iteration = 10000
total_reward, dataset = run_mppi(mppi=mppi_gym, env=env, retrain_dynamics=train, retrain_after_iter=50, iter=iteration, render=False)

print("Average reward: ", total_reward / iteration)
# Out:
# INFO: Making new env: Pendulum-v1
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3296 reward received: -0.5428 time taken: 0.00282s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 2.6341 reward received: -0.6857 time taken: 0.00237s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 3.6817 reward received: -0.8230 time taken: 0.00238s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 4.4110 reward received: -1.0076 time taken: 0.00234s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 2.8015 reward received: -1.2541 time taken: 0.00230s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.1592 reward received: -1.5782 time taken: 0.00238s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.4866 reward received: -2.0829 time taken: 0.00235s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1346 reward received: -2.8372 time taken: 0.00234s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.0757 reward received: -3.8953 time taken: 0.00245s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1070 reward received: -5.1179 time taken: 0.00233s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.0252 reward received: -6.7860 time taken: 0.00232s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.0080 reward received: -9.0050 time taken: 0.00246s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.5307 reward received: -11.5469 time taken: 0.00233s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.5383 reward received: -14.4000 time taken: 0.00251s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0798 reward received: -13.7996 time taken: 0.00413s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.3372 reward received: -11.5879 time taken: 0.00363s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.4648 reward received: -9.6128 time taken: 0.00232s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3799 reward received: -7.4289 time taken: 0.00262s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.3198 reward received: -5.5619 time taken: 0.00416s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0045 reward received: -4.2550 time taken: 0.00379s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.1504 reward received: -3.0610 time taken: 0.00389s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.1825 reward received: -2.1798 time taken: 0.00403s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -2.4505 reward received: -1.4358 time taken: 0.00306s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.5422 reward received: -1.1138 time taken: 0.00245s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.7422 reward received: -0.7952 time taken: 0.00228s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -2.3003 reward received: -0.5141 time taken: 0.00245s
# [DEBUG 04-06 16:50:39 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0180 reward received: -0.4227 time taken: 0.00245s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0906 reward received: -0.2871 time taken: 0.00245s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0172 reward received: -0.1973 time taken: 0.00238s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3642 reward received: -0.1333 time taken: 0.00224s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.9067 reward received: -0.0976 time taken: 0.00229s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3771 reward received: -0.0814 time taken: 0.00236s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2854 reward received: -0.0498 time taken: 0.00237s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.5067 reward received: -0.0376 time taken: 0.00264s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.0285 reward received: -0.0215 time taken: 0.00234s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.7434 reward received: -0.0121 time taken: 0.00231s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.7256 reward received: -0.0155 time taken: 0.00259s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0065 reward received: -0.0064 time taken: 0.00250s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.7976 reward received: -0.0078 time taken: 0.00238s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3019 reward received: -0.0125 time taken: 0.00275s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.9378 reward received: -0.0079 time taken: 0.00237s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.6807 reward received: -0.0019 time taken: 0.00229s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.5838 reward received: -0.0055 time taken: 0.00251s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3323 reward received: -0.0015 time taken: 0.00267s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.0791 reward received: -0.0022 time taken: 0.00261s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.6244 reward received: -0.0016 time taken: 0.00247s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.4927 reward received: -0.0029 time taken: 0.00239s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.4824 reward received: -0.0037 time taken: 0.00252s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.1455 reward received: -0.0023 time taken: 0.00249s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.5320 reward received: -0.0032 time taken: 0.00352s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.5261 reward received: -0.0022 time taken: 0.00348s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.5161 reward received: -0.0006 time taken: 0.00283s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 2.2176 reward received: -0.0056 time taken: 0.00250s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4845 reward received: -0.0032 time taken: 0.00245s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.6543 reward received: -0.0017 time taken: 0.00232s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0008 reward received: -0.0002 time taken: 0.00232s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4480 reward received: -0.0005 time taken: 0.00247s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2459 reward received: -0.0003 time taken: 0.00251s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.8286 reward received: -0.0011 time taken: 0.00243s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0712 reward received: -0.0031 time taken: 0.00272s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.6961 reward received: -0.0065 time taken: 0.00253s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.6835 reward received: -0.0009 time taken: 0.00269s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.0192 reward received: -0.0013 time taken: 0.00331s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.5974 reward received: -0.0014 time taken: 0.00389s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.7294 reward received: -0.0005 time taken: 0.00372s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.3159 reward received: -0.0029 time taken: 0.00365s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4189 reward received: -0.0010 time taken: 0.00314s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0351 reward received: -0.0001 time taken: 0.00262s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.7357 reward received: -0.0006 time taken: 0.00401s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1547 reward received: -0.0016 time taken: 0.00396s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.0440 reward received: -0.0036 time taken: 0.00385s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.2658 reward received: -0.0125 time taken: 0.00378s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.1258 reward received: -0.0035 time taken: 0.00374s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -2.3366 reward received: -0.0084 time taken: 0.00340s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1407 reward received: -0.0027 time taken: 0.00368s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.5644 reward received: -0.0019 time taken: 0.00350s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.2932 reward received: -0.0034 time taken: 0.00236s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.2572 reward received: -0.0024 time taken: 0.00222s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.7436 reward received: -0.0017 time taken: 0.00224s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.5645 reward received: -0.0028 time taken: 0.00224s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0816 reward received: -0.0006 time taken: 0.00235s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.0951 reward received: -0.0017 time taken: 0.00230s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.4162 reward received: -0.0056 time taken: 0.00218s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.2772 reward received: -0.0019 time taken: 0.00215s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2198 reward received: -0.0023 time taken: 0.00213s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.1610 reward received: -0.0046 time taken: 0.00228s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.8042 reward received: -0.0007 time taken: 0.00233s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.7402 reward received: -0.0017 time taken: 0.00267s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0197 reward received: -0.0000 time taken: 0.00236s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4608 reward received: -0.0002 time taken: 0.00235s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.0195 reward received: -0.0016 time taken: 0.00225s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1862 reward received: -0.0006 time taken: 0.00224s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0059 reward received: -0.0010 time taken: 0.00242s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4543 reward received: -0.0014 time taken: 0.00254s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.6154 reward received: -0.0007 time taken: 0.00247s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.4974 reward received: -0.0025 time taken: 0.00231s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.5633 reward received: -0.0063 time taken: 0.00233s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.8067 reward received: -0.0010 time taken: 0.00234s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.5634 reward received: -0.0045 time taken: 0.00220s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.1699 reward received: -0.0150 time taken: 0.00213s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.9109 reward received: -0.0079 time taken: 0.00215s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1397 reward received: -0.0008 time taken: 0.00236s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3539 reward received: -0.0009 time taken: 0.00235s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.8911 reward received: -0.0025 time taken: 0.00248s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.9572 reward received: -0.0106 time taken: 0.00244s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.1082 reward received: -0.0014 time taken: 0.00237s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.9055 reward received: -0.0044 time taken: 0.00229s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1181 reward received: -0.0003 time taken: 0.00218s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3611 reward received: -0.0003 time taken: 0.00215s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4028 reward received: -0.0002 time taken: 0.00232s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.5498 reward received: -0.0007 time taken: 0.00248s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.6873 reward received: -0.0006 time taken: 0.00260s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.3457 reward received: -0.0032 time taken: 0.00230s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.6608 reward received: -0.0013 time taken: 0.00227s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.8953 reward received: -0.0008 time taken: 0.00222s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.6364 reward received: -0.0022 time taken: 0.00225s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.3796 reward received: -0.0074 time taken: 0.00244s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -2.1959 reward received: -0.0043 time taken: 0.00346s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.2083 reward received: -0.0067 time taken: 0.00227s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3909 reward received: -0.0054 time taken: 0.00225s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.5063 reward received: -0.0057 time taken: 0.00228s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0593 reward received: -0.0004 time taken: 0.00237s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2626 reward received: -0.0004 time taken: 0.00352s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2824 reward received: -0.0004 time taken: 0.00228s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.4200 reward received: -0.0012 time taken: 0.00232s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.6387 reward received: -0.0010 time taken: 0.00235s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0475 reward received: -0.0007 time taken: 0.00232s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2273 reward received: -0.0005 time taken: 0.00308s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0654 reward received: -0.0004 time taken: 0.00243s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.1528 reward received: -0.0018 time taken: 0.00238s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4108 reward received: -0.0022 time taken: 0.00353s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1311 reward received: -0.0005 time taken: 0.00351s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3472 reward received: -0.0007 time taken: 0.00327s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.6048 reward received: -0.0019 time taken: 0.00317s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.0068 reward received: -0.0011 time taken: 0.00372s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2375 reward received: -0.0036 time taken: 0.00343s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.9758 reward received: -0.0038 time taken: 0.00315s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.2507 reward received: -0.0020 time taken: 0.00316s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0580 reward received: -0.0023 time taken: 0.00309s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.6835 reward received: -0.0022 time taken: 0.00294s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.1174 reward received: -0.0064 time taken: 0.00344s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2114 reward received: -0.0005 time taken: 0.00342s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.0927 reward received: -0.0024 time taken: 0.00302s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.6337 reward received: -0.0008 time taken: 0.00306s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.8977 reward received: -0.0012 time taken: 0.00315s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3544 reward received: -0.0008 time taken: 0.00251s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2246 reward received: -0.0001 time taken: 0.00236s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.1747 reward received: -0.0002 time taken: 0.00223s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.4529 reward received: -0.0007 time taken: 0.00207s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0374 reward received: -0.0001 time taken: 0.00222s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2363 reward received: -0.0002 time taken: 0.00238s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.8816 reward received: -0.0012 time taken: 0.00243s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3698 reward received: -0.0008 time taken: 0.00228s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3296 reward received: -0.0016 time taken: 0.00223s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.7800 reward received: -0.0035 time taken: 0.00228s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.5159 reward received: -0.0006 time taken: 0.00224s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3597 reward received: -0.0002 time taken: 0.00228s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0519 reward received: -0.0002 time taken: 0.00236s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0385 reward received: -0.0004 time taken: 0.00237s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4851 reward received: -0.0008 time taken: 0.00225s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.4290 reward received: -0.0004 time taken: 0.00218s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0043 reward received: -0.0008 time taken: 0.00224s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.7681 reward received: -0.0017 time taken: 0.00234s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1429 reward received: -0.0005 time taken: 0.00240s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.8125 reward received: -0.0012 time taken: 0.00235s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3362 reward received: -0.0011 time taken: 0.00234s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.7720 reward received: -0.0009 time taken: 0.00226s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.8787 reward received: -0.0051 time taken: 0.00225s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 2.3913 reward received: -0.0067 time taken: 0.00228s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.1292 reward received: -0.0040 time taken: 0.00227s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.8526 reward received: -0.0012 time taken: 0.00244s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3950 reward received: -0.0029 time taken: 0.00223s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.5822 reward received: -0.0025 time taken: 0.00218s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.5873 reward received: -0.0017 time taken: 0.00209s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.1152 reward received: -0.0055 time taken: 0.00225s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -3.0111 reward received: -0.0060 time taken: 0.00239s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0785 reward received: -0.0071 time taken: 0.00289s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.3013 reward received: -0.0076 time taken: 0.00297s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3710 reward received: -0.0005 time taken: 0.00255s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.5883 reward received: -0.0010 time taken: 0.00288s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.5524 reward received: -0.0025 time taken: 0.00290s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.1593 reward received: -0.0063 time taken: 0.00369s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0163 reward received: -0.0003 time taken: 0.00344s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.1319 reward received: -0.0004 time taken: 0.00361s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.0021 reward received: -0.0018 time taken: 0.00361s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4390 reward received: -0.0007 time taken: 0.00348s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.8994 reward received: -0.0009 time taken: 0.00293s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.0717 reward received: -0.0025 time taken: 0.00268s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.0185 reward received: -0.0086 time taken: 0.00265s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.1008 reward received: -0.0031 time taken: 0.00252s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.1740 reward received: -0.0017 time taken: 0.00220s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.0590 reward received: -0.0048 time taken: 0.00230s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3256 reward received: -0.0002 time taken: 0.00239s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2710 reward received: -0.0006 time taken: 0.00246s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3254 reward received: -0.0015 time taken: 0.00235s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3723 reward received: -0.0007 time taken: 0.00236s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3982 reward received: -0.0003 time taken: 0.00230s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.5100 reward received: -0.0004 time taken: 0.00216s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -2.1421 reward received: -0.0050 time taken: 0.00230s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.1715 reward received: -0.0058 time taken: 0.00251s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1502 reward received: -0.0005 time taken: 0.00230s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.1479 reward received: -0.0017 time taken: 0.00234s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 2.3994 reward received: -0.0095 time taken: 0.00229s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.7235 reward received: -0.0016 time taken: 0.00223s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.7209 reward received: -0.0018 time taken: 0.00223s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3236 reward received: -0.0009 time taken: 0.00241s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0766 reward received: -0.0009 time taken: 0.00280s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3048 reward received: -0.0007 time taken: 0.00244s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.2705 reward received: -0.0008 time taken: 0.00229s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0792 reward received: -0.0008 time taken: 0.00227s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.2609 reward received: -0.0005 time taken: 0.00225s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.7775 reward received: -0.0013 time taken: 0.00239s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.6636 reward received: -0.0010 time taken: 0.00236s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2006 reward received: -0.0003 time taken: 0.00237s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0883 reward received: -0.0003 time taken: 0.00223s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.5373 reward received: -0.0006 time taken: 0.00224s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.8229 reward received: -0.0012 time taken: 0.00231s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1001 reward received: -0.0009 time taken: 0.00246s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.6461 reward received: -0.0014 time taken: 0.00247s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.6545 reward received: -0.0008 time taken: 0.00229s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.2471 reward received: -0.0033 time taken: 0.00229s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0072 reward received: -0.0009 time taken: 0.00226s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.8296 reward received: -0.0013 time taken: 0.00240s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0049 reward received: -0.0015 time taken: 0.00240s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.2332 reward received: -0.0037 time taken: 0.00238s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.6681 reward received: -0.0015 time taken: 0.00229s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.4178 reward received: -0.0023 time taken: 0.00224s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.4706 reward received: -0.0054 time taken: 0.00232s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -2.4235 reward received: -0.0190 time taken: 0.00304s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.0524 reward received: -0.0021 time taken: 0.00348s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2461 reward received: -0.0005 time taken: 0.00357s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.8643 reward received: -0.0043 time taken: 0.00269s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.8325 reward received: -0.0169 time taken: 0.00266s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.4165 reward received: -0.0034 time taken: 0.00347s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.1615 reward received: -0.0012 time taken: 0.00299s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4699 reward received: -0.0007 time taken: 0.00236s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1777 reward received: -0.0002 time taken: 0.00234s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0372 reward received: -0.0002 time taken: 0.00229s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.8394 reward received: -0.0009 time taken: 0.00247s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.3403 reward received: -0.0041 time taken: 0.00247s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.1083 reward received: -0.0005 time taken: 0.00252s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.1478 reward received: -0.0003 time taken: 0.00226s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.7013 reward received: -0.0008 time taken: 0.00230s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.7117 reward received: -0.0013 time taken: 0.00238s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.6706 reward received: -0.0034 time taken: 0.00251s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3348 reward received: -0.0006 time taken: 0.00233s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1411 reward received: -0.0000 time taken: 0.00238s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1904 reward received: -0.0002 time taken: 0.00241s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2763 reward received: -0.0005 time taken: 0.00231s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.4755 reward received: -0.0023 time taken: 0.00232s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.1863 reward received: -0.0080 time taken: 0.00239s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.4230 reward received: -0.0014 time taken: 0.00228s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.4501 reward received: -0.0058 time taken: 0.00240s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4901 reward received: -0.0012 time taken: 0.00229s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.9576 reward received: -0.0022 time taken: 0.00224s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3621 reward received: -0.0046 time taken: 0.00261s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1298 reward received: -0.0020 time taken: 0.00238s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3990 reward received: -0.0015 time taken: 0.00234s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.1698 reward received: -0.0003 time taken: 0.00234s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.3901 reward received: -0.0026 time taken: 0.00227s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3705 reward received: -0.0017 time taken: 0.00240s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.8911 reward received: -0.0070 time taken: 0.00305s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.5824 reward received: -0.0012 time taken: 0.00370s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.1260 reward received: -0.0013 time taken: 0.00360s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.0026 reward received: -0.0042 time taken: 0.00379s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.1331 reward received: -0.0004 time taken: 0.00322s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4912 reward received: -0.0006 time taken: 0.00231s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3155 reward received: -0.0005 time taken: 0.00252s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0732 reward received: -0.0007 time taken: 0.00226s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.5750 reward received: -0.0007 time taken: 0.00225s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1224 reward received: -0.0003 time taken: 0.00303s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.7532 reward received: -0.0038 time taken: 0.00338s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.8094 reward received: -0.0041 time taken: 0.00292s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.5521 reward received: -0.0006 time taken: 0.00229s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.8859 reward received: -0.0027 time taken: 0.00221s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2037 reward received: -0.0001 time taken: 0.00233s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.2249 reward received: -0.0003 time taken: 0.00226s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3591 reward received: -0.0002 time taken: 0.00219s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.5131 reward received: -0.0004 time taken: 0.00227s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.5549 reward received: -0.0027 time taken: 0.00229s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.1230 reward received: -0.0033 time taken: 0.00222s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.8983 reward received: -0.0063 time taken: 0.00226s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3067 reward received: -0.0014 time taken: 0.00240s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.7332 reward received: -0.0055 time taken: 0.00235s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.5515 reward received: -0.0013 time taken: 0.00222s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.4612 reward received: -0.0002 time taken: 0.00225s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.5574 reward received: -0.0011 time taken: 0.00226s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.5495 reward received: -0.0003 time taken: 0.00233s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.4758 reward received: -0.0032 time taken: 0.00235s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3137 reward received: -0.0016 time taken: 0.00235s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.4610 reward received: -0.0029 time taken: 0.00231s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.0929 reward received: -0.0022 time taken: 0.00221s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.2888 reward received: -0.0005 time taken: 0.00222s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.9220 reward received: -0.0047 time taken: 0.00231s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.8970 reward received: -0.0044 time taken: 0.00237s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.7163 reward received: -0.0010 time taken: 0.00239s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.9413 reward received: -0.0011 time taken: 0.00243s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.1230 reward received: -0.0016 time taken: 0.00237s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.4945 reward received: -0.0048 time taken: 0.00276s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.9190 reward received: -0.0017 time taken: 0.00366s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.7749 reward received: -0.0042 time taken: 0.00322s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4715 reward received: -0.0007 time taken: 0.00261s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.7195 reward received: -0.0006 time taken: 0.00266s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.6950 reward received: -0.0024 time taken: 0.00239s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.7592 reward received: -0.0035 time taken: 0.00235s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.8797 reward received: -0.0054 time taken: 0.00368s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.8032 reward received: -0.0038 time taken: 0.00246s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.1457 reward received: -0.0053 time taken: 0.00227s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2385 reward received: -0.0004 time taken: 0.00224s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.0386 reward received: -0.0021 time taken: 0.00246s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.9249 reward received: -0.0015 time taken: 0.00241s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3529 reward received: -0.0037 time taken: 0.00227s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.7763 reward received: -0.0049 time taken: 0.00229s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1805 reward received: -0.0019 time taken: 0.00225s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.1144 reward received: -0.0014 time taken: 0.00250s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 2.8533 reward received: -0.0063 time taken: 0.00242s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.7577 reward received: -0.0028 time taken: 0.00237s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.0212 reward received: -0.0012 time taken: 0.00241s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.5199 reward received: -0.0052 time taken: 0.00230s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.5734 reward received: -0.0007 time taken: 0.00230s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.9448 reward received: -0.0010 time taken: 0.00262s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.5305 reward received: -0.0040 time taken: 0.00249s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1946 reward received: -0.0010 time taken: 0.00241s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.0438 reward received: -0.0026 time taken: 0.00230s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3741 reward received: -0.0002 time taken: 0.00230s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3014 reward received: -0.0001 time taken: 0.00231s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3097 reward received: -0.0006 time taken: 0.00247s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3389 reward received: -0.0002 time taken: 0.00249s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.5328 reward received: -0.0010 time taken: 0.00226s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3151 reward received: -0.0032 time taken: 0.00231s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0623 reward received: -0.0024 time taken: 0.00229s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.7001 reward received: -0.0066 time taken: 0.00226s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.6538 reward received: -0.0018 time taken: 0.00246s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.2464 reward received: -0.0026 time taken: 0.00238s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.9049 reward received: -0.0020 time taken: 0.00228s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -2.8984 reward received: -0.0087 time taken: 0.00224s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 2.9602 reward received: -0.0303 time taken: 0.00231s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.6085 reward received: -0.0085 time taken: 0.00262s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 2.6167 reward received: -0.0049 time taken: 0.00242s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.4764 reward received: -0.0079 time taken: 0.00415s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.2958 reward received: -0.0126 time taken: 0.00395s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4931 reward received: -0.0021 time taken: 0.00393s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2638 reward received: -0.0006 time taken: 0.00367s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.3394 reward received: -0.0004 time taken: 0.00336s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.5719 reward received: -0.0036 time taken: 0.00236s
# [DEBUG 04-06 16:50:40 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.1529 reward received: -0.0018 time taken: 0.00344s
# [DEBUG 04-06 16:50:41 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.8949 reward received: -0.0029 time taken: 0.00264s
# [DEBUG 04-06 16:50:41 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.8043 reward received: -0.0007 time taken: 0.00253s
# [DEBUG 04-06 16:50:41 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.9869 reward received: -0.0023 time taken: 0.00234s
# [DEBUG 04-06 16:50:41 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.0499 reward received: -0.0012 time taken: 0.00220s
# [DEBUG 04-06 16:50:41 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -2.2001 reward received: -0.0060 time taken: 0.00252s
# [DEBUG 04-06 16:50:41 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.0122 reward received: -0.0035 time taken: 0.00241s
# [DEBUG 04-06 16:50:41 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1951 reward received: -0.0001 time taken: 0.00228s
# [DEBUG 04-06 16:50:41 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.5974 reward received: -0.0005 time taken: 0.00239s
# [DEBUG 04-06 16:50:41 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0798 reward received: -0.0018 time taken: 0.00227s
# [DEBUG 04-06 16:50:41 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0577 reward received: -0.0020 time taken: 0.00251s
# [DEBUG 04-06 16:50:41 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.8560 reward received: -0.0037 time taken: 0.00282s
# [DEBUG 04-06 16:50:41 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -2.7867 reward received: -0.0147 time taken: 0.00263s
# [DEBUG 04-06 16:50:41 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.3411 reward received: -0.0038 time taken: 0.00262s
# [DEBUG 04-06 16:50:41 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -2.6577 reward received: -0.0142 time taken: 0.00261s
# [DEBUG 04-06 16:50:41 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.7399 reward received: -0.0038 time taken: 0.00236s
# [DEBUG 04-06 16:50:41 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.9178 reward received: -0.0041 time taken: 0.00248s
# [DEBUG 04-06 16:50:41 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.9244 reward received: -0.0055 time taken: 0.00259s
# [DEBUG 04-06 16:50:41 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2083 reward received: -0.0081 time taken: 0.00259s
# ...
# [DEBUG 04-06 16:51:15 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0085 reward received: -0.0005 time taken: 0.00243s
# [DEBUG 04-06 16:51:15 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0694 reward received: -0.0005 time taken: 0.00289s
# [DEBUG 04-06 16:51:15 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.0842 reward received: -0.0017 time taken: 0.00235s
# [DEBUG 04-06 16:51:15 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.7681 reward received: -0.0078 time taken: 0.00224s
# [DEBUG 04-06 16:51:15 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1202 reward received: -0.0011 time taken: 0.00239s
# [DEBUG 04-06 16:51:15 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.0150 reward received: -0.0020 time taken: 0.00355s
# [DEBUG 04-06 16:51:15 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.0079 reward received: -0.0037 time taken: 0.00344s
# [DEBUG 04-06 16:51:15 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3661 reward received: -0.0012 time taken: 0.00348s
# [DEBUG 04-06 16:51:15 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.4973 reward received: -0.0043 time taken: 0.00331s
# [DEBUG 04-06 16:51:15 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3994 reward received: -0.0025 time taken: 0.00369s
# [DEBUG 04-06 16:51:15 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.8724 reward received: -0.0018 time taken: 0.00371s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3721 reward received: -0.0027 time taken: 0.00335s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.4438 reward received: -0.0010 time taken: 0.00283s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1637 reward received: -0.0017 time taken: 0.00255s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.8934 reward received: -0.0027 time taken: 0.00405s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4829 reward received: -0.0003 time taken: 0.00263s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.5875 reward received: -0.0011 time taken: 0.00247s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.9338 reward received: -0.0010 time taken: 0.00312s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.3624 reward received: -0.0043 time taken: 0.00257s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.2889 reward received: -0.0005 time taken: 0.00278s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.1442 reward received: -0.0020 time taken: 0.00261s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.6995 reward received: -0.0087 time taken: 0.00250s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.9777 reward received: -0.0010 time taken: 0.00262s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0814 reward received: -0.0026 time taken: 0.00242s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.2584 reward received: -0.0035 time taken: 0.00281s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.6442 reward received: -0.0033 time taken: 0.00262s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3073 reward received: -0.0014 time taken: 0.00243s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.4640 reward received: -0.0033 time taken: 0.00247s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.9675 reward received: -0.0063 time taken: 0.00234s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0803 reward received: -0.0039 time taken: 0.00232s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.8883 reward received: -0.0032 time taken: 0.00257s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3144 reward received: -0.0065 time taken: 0.00246s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.5913 reward received: -0.0042 time taken: 0.00263s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.6764 reward received: -0.0039 time taken: 0.00265s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4503 reward received: -0.0023 time taken: 0.00270s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.8566 reward received: -0.0055 time taken: 0.00263s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0361 reward received: -0.0013 time taken: 0.00249s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.8028 reward received: -0.0026 time taken: 0.00270s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.7030 reward received: -0.0107 time taken: 0.00249s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.1999 reward received: -0.0016 time taken: 0.00358s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.9243 reward received: -0.0034 time taken: 0.00367s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1329 reward received: -0.0018 time taken: 0.00368s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2626 reward received: -0.0018 time taken: 0.00376s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.1675 reward received: -0.0037 time taken: 0.00337s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1208 reward received: -0.0023 time taken: 0.00364s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.7737 reward received: -0.0050 time taken: 0.00383s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.5786 reward received: -0.0103 time taken: 0.00377s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -2.1679 reward received: -0.0083 time taken: 0.00424s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.5958 reward received: -0.0039 time taken: 0.00324s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2518 reward received: -0.0017 time taken: 0.00327s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.2805 reward received: -0.0007 time taken: 0.00286s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.8804 reward received: -0.0021 time taken: 0.00248s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.8584 reward received: -0.0008 time taken: 0.00248s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.3883 reward received: -0.0032 time taken: 0.00253s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1039 reward received: -0.0009 time taken: 0.00343s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1299 reward received: -0.0007 time taken: 0.00243s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1093 reward received: -0.0005 time taken: 0.00228s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.8880 reward received: -0.0012 time taken: 0.00251s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.4941 reward received: -0.0043 time taken: 0.00327s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 2.1718 reward received: -0.0065 time taken: 0.00316s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.2960 reward received: -0.0026 time taken: 0.00254s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -3.4610 reward received: -0.0073 time taken: 0.00277s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 3.0431 reward received: -0.0060 time taken: 0.00274s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -2.2262 reward received: -0.0066 time taken: 0.00262s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.0979 reward received: -0.0037 time taken: 0.00260s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.1062 reward received: -0.0003 time taken: 0.00355s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 2.6183 reward received: -0.0043 time taken: 0.00348s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.6270 reward received: -0.0074 time taken: 0.00268s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.1380 reward received: -0.0041 time taken: 0.00338s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1428 reward received: -0.0000 time taken: 0.00324s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.3356 reward received: -0.0002 time taken: 0.00238s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.4875 reward received: -0.0003 time taken: 0.00222s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.5644 reward received: -0.0007 time taken: 0.00214s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.1395 reward received: -0.0001 time taken: 0.00220s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4378 reward received: -0.0004 time taken: 0.00258s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4816 reward received: -0.0013 time taken: 0.00322s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.8490 reward received: -0.0066 time taken: 0.00346s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.5280 reward received: -0.0033 time taken: 0.00362s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.7367 reward received: -0.0026 time taken: 0.00364s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.6958 reward received: -0.0032 time taken: 0.00263s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4663 reward received: -0.0045 time taken: 0.00300s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.5654 reward received: -0.0022 time taken: 0.00265s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.6760 reward received: -0.0008 time taken: 0.00249s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0169 reward received: -0.0027 time taken: 0.00296s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.2484 reward received: -0.0049 time taken: 0.00244s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.0920 reward received: -0.0005 time taken: 0.00245s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.6755 reward received: -0.0011 time taken: 0.00248s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.5220 reward received: -0.0010 time taken: 0.00258s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.3267 reward received: -0.0034 time taken: 0.00240s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.9985 reward received: -0.0023 time taken: 0.00222s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.6665 reward received: -0.0009 time taken: 0.00238s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.4324 reward received: -0.0020 time taken: 0.00305s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.5538 reward received: -0.0007 time taken: 0.00352s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.6902 reward received: -0.0046 time taken: 0.00347s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.5401 reward received: -0.0174 time taken: 0.00312s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.4764 reward received: -0.0036 time taken: 0.00350s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 3.6548 reward received: -0.0063 time taken: 0.00332s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.3065 reward received: -0.0049 time taken: 0.00324s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.1796 reward received: -0.0009 time taken: 0.00334s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.9420 reward received: -0.0018 time taken: 0.00350s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.2091 reward received: -0.0012 time taken: 0.00237s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.2463 reward received: -0.0006 time taken: 0.00238s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.1373 reward received: -0.0007 time taken: 0.00330s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.4848 reward received: -0.0006 time taken: 0.00239s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.1805 reward received: -0.0022 time taken: 0.00223s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.1540 reward received: -0.0031 time taken: 0.00254s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0885 reward received: -0.0005 time taken: 0.00284s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.5006 reward received: -0.0006 time taken: 0.00341s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.7467 reward received: -0.0013 time taken: 0.00348s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.9334 reward received: -0.0040 time taken: 0.00352s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.6640 reward received: -0.0006 time taken: 0.00362s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.4197 reward received: -0.0018 time taken: 0.00349s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.9596 reward received: -0.0048 time taken: 0.00307s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.4163 reward received: -0.0007 time taken: 0.00290s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.2148 reward received: -0.0003 time taken: 0.00282s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.5393 reward received: -0.0009 time taken: 0.00236s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -0.0172 reward received: -0.0003 time taken: 0.00227s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 0.2489 reward received: -0.0004 time taken: 0.00251s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: -1.5996 reward received: -0.0031 time taken: 0.00241s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.2857 reward received: -0.0050 time taken: 0.00346s
# [DEBUG 04-06 16:51:16 /tmp/ipykernel_2035864/1717595129.py:369] action taken: 1.1400 reward received: -0.0015 time taken: 0.00232s
# Average reward:  -0.0150339514693082

# %%
for i in range(100):
    env.close()
